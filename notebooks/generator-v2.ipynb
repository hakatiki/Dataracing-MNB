# %%
from generator import *

# %%
## LEGJOBB BEADÁS
# DO NOT TOUCH
params={
    'RUN_NAME': 'default-1.58-2.08-650-11-150-0.005',
    'LR_R': 1.58,
    'RF_R': 2.08,
    'RF_N': 650,
    'RF_D': 11,
    'RF_L': 150,
    'FEATURES':0.005,
}
gen(params)
# Out:
# TARGET_EVENT_BINARY
# 0    1590792
# 1      10871
# Name: count, dtype: int64
# TARGET_EVENT_BINARY_2Y
# 0    1591751
# 1       9912
# Name: count, dtype: int64
# TARGET_EVENT_BINARY_1Y
# 0    1596927
# 1       4736
# Name: count, dtype: int64
# TARGET_EVENT_BINARY_6M
# 0    1601267
# 1        396
# Name: count, dtype: int64
# Variables removed: {'BORROWER_COUNTRY', 'CONTRACT_REFINANCED', 'FREQ_TYPE_2f88e16c'}
# LOAN_TYPE_47693941
# LOAN_TYPE_8fe006f1
# LOAN_TYPE_cde77491
# FREQ_TYPE_bd092d5a
# MORTGAGE_TYPE_3.0
# MORTGAGE_TYPE_10.0
# MORTGAGE_TYPE_41.0
# MORTGAGE_TYPE_42.0
# MORTGAGE_TYPE_43.0
# MORTGAGE_TYPE_47.0
# ['LOAN_TYPE_694cbaee', 'LOAN_TYPE_0aeb4094', 'LOAN_TYPE_eab72d7a', 'LOAN_TYPE_95c4f8fb', 'LOAN_TYPE_f792971b', 'LOAN_TYPE_cde77491', 'LOAN_TYPE_47693941', 'LOAN_TYPE_8fe006f1']
# LOAN_TYPE_694cbaee
# LOAN_TYPE_eab72d7a
# LOAN_TYPE_95c4f8fb
# LOAN_TYPE_f792971b
# 0
# 0
# 0
# 0
# ...
#          Current function value: 0.014681
#          Iterations: 35
# ...

# %%
# SOTA 240
params={
    'RUN_NAME': 'default-1.58-2.08-650-11-160-0.005',
    'LR_R': 1.58,
    'RF_R': 2.08,
    'RF_N': 650,
    'RF_D': 11,
    'RF_L': 180,
    'FEATURES':0.005,
}
gen(params)
# Out:
# TARGET_EVENT_BINARY
# 0    1590792
# 1      10871
# Name: count, dtype: int64
# TARGET_EVENT_BINARY_2Y
# 0    1591751
# 1       9912
# Name: count, dtype: int64
# TARGET_EVENT_BINARY_1Y
# 0    1596927
# 1       4736
# Name: count, dtype: int64
# TARGET_EVENT_BINARY_6M
# 0    1601267
# 1        396
# Name: count, dtype: int64
# Variables removed: {'BORROWER_COUNTRY', 'CONTRACT_REFINANCED', 'FREQ_TYPE_2f88e16c'}
# LOAN_TYPE_47693941
# LOAN_TYPE_8fe006f1
# LOAN_TYPE_cde77491
# FREQ_TYPE_bd092d5a
# MORTGAGE_TYPE_3.0
# MORTGAGE_TYPE_10.0
# MORTGAGE_TYPE_41.0
# MORTGAGE_TYPE_42.0
# MORTGAGE_TYPE_43.0
# MORTGAGE_TYPE_47.0
# ['LOAN_TYPE_694cbaee', 'LOAN_TYPE_0aeb4094', 'LOAN_TYPE_eab72d7a', 'LOAN_TYPE_95c4f8fb', 'LOAN_TYPE_f792971b', 'LOAN_TYPE_cde77491', 'LOAN_TYPE_47693941', 'LOAN_TYPE_8fe006f1']
# LOAN_TYPE_694cbaee
# LOAN_TYPE_eab72d7a
# LOAN_TYPE_95c4f8fb
# LOAN_TYPE_f792971b
# 0
# 0
# 0
# 0
# ...
#          Current function value: 0.014681
#          Iterations: 35
# ...

# %%
params={
    'RUN_NAME': 'default-1.58-2.00-650-11-200-0.005',
    'LR_R': 1.58,
    'RF_R': 2.00,
    'RF_N': 650,
    'RF_D': 11,
    'RF_L': 200,
    'FEATURES':0.005,
}
gen(params)
# Out:
# TARGET_EVENT_BINARY
# 0    1590792
# 1      10871
# Name: count, dtype: int64
# TARGET_EVENT_BINARY_2Y
# 0    1591751
# 1       9912
# Name: count, dtype: int64
# TARGET_EVENT_BINARY_1Y
# 0    1596927
# 1       4736
# Name: count, dtype: int64
# TARGET_EVENT_BINARY_6M
# 0    1601267
# 1        396
# Name: count, dtype: int64
# Variables removed: {'BORROWER_COUNTRY', 'CONTRACT_REFINANCED', 'FREQ_TYPE_2f88e16c'}
# LOAN_TYPE_47693941
# LOAN_TYPE_8fe006f1
# LOAN_TYPE_cde77491
# FREQ_TYPE_bd092d5a
# MORTGAGE_TYPE_3.0
# MORTGAGE_TYPE_10.0
# MORTGAGE_TYPE_41.0
# MORTGAGE_TYPE_42.0
# MORTGAGE_TYPE_43.0
# MORTGAGE_TYPE_47.0
# ['LOAN_TYPE_694cbaee', 'LOAN_TYPE_0aeb4094', 'LOAN_TYPE_eab72d7a', 'LOAN_TYPE_95c4f8fb', 'LOAN_TYPE_f792971b', 'LOAN_TYPE_cde77491', 'LOAN_TYPE_47693941', 'LOAN_TYPE_8fe006f1']
# LOAN_TYPE_694cbaee
# LOAN_TYPE_eab72d7a
# LOAN_TYPE_95c4f8fb
# LOAN_TYPE_f792971b
# 0
# 0
# 0
# 0
# ...
#          Current function value: 0.014681
#          Iterations: 35
# ...

# %%
# {"Logloss": 0.023893212628573093, "ROCAUC": 0.9824958667154974}
params={
    'RUN_NAME': 'default-1.58-2.08-610-11-500-0.005',
    'LR_R': 1.58,
    'RF_R': 2.08,
    'RF_N': 610,
    'RF_D': 11,
    'RF_L': 500,
    'FEATURES':0.005,
}
gen(params)
# Out:
# TARGET_EVENT_BINARY
# 0    1590792
# 1      10871
# Name: count, dtype: int64
# TARGET_EVENT_BINARY_2Y
# 0    1591751
# 1       9912
# Name: count, dtype: int64
# TARGET_EVENT_BINARY_1Y
# 0    1596927
# 1       4736
# Name: count, dtype: int64
# TARGET_EVENT_BINARY_6M
# 0    1601267
# 1        396
# Name: count, dtype: int64
# Variables removed: {'BORROWER_COUNTRY', 'CONTRACT_REFINANCED', 'FREQ_TYPE_2f88e16c'}
# LOAN_TYPE_47693941
# LOAN_TYPE_8fe006f1
# LOAN_TYPE_cde77491
# FREQ_TYPE_bd092d5a
# MORTGAGE_TYPE_3.0
# MORTGAGE_TYPE_10.0
# MORTGAGE_TYPE_41.0
# MORTGAGE_TYPE_42.0
# MORTGAGE_TYPE_43.0
# MORTGAGE_TYPE_47.0
# ['LOAN_TYPE_694cbaee', 'LOAN_TYPE_0aeb4094', 'LOAN_TYPE_eab72d7a', 'LOAN_TYPE_95c4f8fb', 'LOAN_TYPE_f792971b', 'LOAN_TYPE_cde77491', 'LOAN_TYPE_47693941', 'LOAN_TYPE_8fe006f1']
# LOAN_TYPE_694cbaee
# LOAN_TYPE_eab72d7a
# LOAN_TYPE_95c4f8fb
# LOAN_TYPE_f792971b
# 0
# 0
# 0
# 0
# ...
#          Current function value: 0.014681
#          Iterations: 35
# ...

# %%
params={
    'RUN_NAME': 'default-1.58-2.08-700-11-750-0.005',
    'LR_R': 1.58,
    'RF_R': 2.08,
    'RF_N': 700,
    'RF_D': 11,
    'RF_L': 750,
    'FEATURES':0.005,
}
gen(params)
# Out:
# TARGET_EVENT_BINARY
# 0    1590792
# 1      10871
# Name: count, dtype: int64
# TARGET_EVENT_BINARY_2Y
# 0    1591751
# 1       9912
# Name: count, dtype: int64
# TARGET_EVENT_BINARY_1Y
# 0    1596927
# 1       4736
# Name: count, dtype: int64
# TARGET_EVENT_BINARY_6M
# 0    1601267
# 1        396
# Name: count, dtype: int64
# Variables removed: {'BORROWER_COUNTRY', 'CONTRACT_REFINANCED', 'FREQ_TYPE_2f88e16c'}
# LOAN_TYPE_47693941
# LOAN_TYPE_8fe006f1
# LOAN_TYPE_cde77491
# FREQ_TYPE_bd092d5a
# MORTGAGE_TYPE_3.0
# MORTGAGE_TYPE_10.0
# MORTGAGE_TYPE_41.0
# MORTGAGE_TYPE_42.0
# MORTGAGE_TYPE_43.0
# MORTGAGE_TYPE_47.0
# ['LOAN_TYPE_694cbaee', 'LOAN_TYPE_0aeb4094', 'LOAN_TYPE_eab72d7a', 'LOAN_TYPE_95c4f8fb', 'LOAN_TYPE_f792971b', 'LOAN_TYPE_cde77491', 'LOAN_TYPE_47693941', 'LOAN_TYPE_8fe006f1']
# LOAN_TYPE_694cbaee
# LOAN_TYPE_eab72d7a
# LOAN_TYPE_95c4f8fb
# LOAN_TYPE_f792971b
# 0
# 0
# 0
# 0
# ...
#          Current function value: 0.014681
#          Iterations: 35
# ...

# %%
params={
    'RUN_NAME': 'default-1.58-2.08-800-11-750-0.005',
    'LR_R': 1.58,
    'RF_R': 2.08,
    'RF_N': 800,
    'RF_D': 11,
    'RF_L': 750,
    'FEATURES':0.005,
}
gen(params)
# Out:
# TARGET_EVENT_BINARY
# 0    1590792
# 1      10871
# Name: count, dtype: int64
# TARGET_EVENT_BINARY_2Y
# 0    1591751
# 1       9912
# Name: count, dtype: int64
# TARGET_EVENT_BINARY_1Y
# 0    1596927
# 1       4736
# Name: count, dtype: int64
# TARGET_EVENT_BINARY_6M
# 0    1601267
# 1        396
# Name: count, dtype: int64
# Variables removed: {'BORROWER_COUNTRY', 'CONTRACT_REFINANCED', 'FREQ_TYPE_2f88e16c'}
# LOAN_TYPE_47693941
# LOAN_TYPE_8fe006f1
# LOAN_TYPE_cde77491
# FREQ_TYPE_bd092d5a
# MORTGAGE_TYPE_3.0
# MORTGAGE_TYPE_10.0
# MORTGAGE_TYPE_41.0
# MORTGAGE_TYPE_42.0
# MORTGAGE_TYPE_43.0
# MORTGAGE_TYPE_47.0
# ['LOAN_TYPE_694cbaee', 'LOAN_TYPE_0aeb4094', 'LOAN_TYPE_eab72d7a', 'LOAN_TYPE_95c4f8fb', 'LOAN_TYPE_f792971b', 'LOAN_TYPE_cde77491', 'LOAN_TYPE_47693941', 'LOAN_TYPE_8fe006f1']
# LOAN_TYPE_694cbaee
# LOAN_TYPE_eab72d7a
# LOAN_TYPE_95c4f8fb
# LOAN_TYPE_f792971b
# 0
# 0
# 0
# 0
# ...
#          Current function value: 0.014681
#          Iterations: 35
# ...

# %%
params={
    'RUN_NAME': 'default-1.58-2.08-800-11-1000-0.005',
    'LR_R': 1.58,
    'RF_R': 2.08,
    'RF_N': 800,
    'RF_D': 11,
    'RF_L': 1000,
    'FEATURES':0.005,
}
gen(params)
# Out:
# TARGET_EVENT_BINARY
# 0    1590792
# 1      10871
# Name: count, dtype: int64
# TARGET_EVENT_BINARY_2Y
# 0    1591751
# 1       9912
# Name: count, dtype: int64
# TARGET_EVENT_BINARY_1Y
# 0    1596927
# 1       4736
# Name: count, dtype: int64
# TARGET_EVENT_BINARY_6M
# 0    1601267
# 1        396
# Name: count, dtype: int64
# Variables removed: {'BORROWER_COUNTRY', 'CONTRACT_REFINANCED', 'FREQ_TYPE_2f88e16c'}
# LOAN_TYPE_47693941
# LOAN_TYPE_8fe006f1
# LOAN_TYPE_cde77491
# FREQ_TYPE_bd092d5a
# MORTGAGE_TYPE_3.0
# MORTGAGE_TYPE_10.0
# MORTGAGE_TYPE_41.0
# MORTGAGE_TYPE_42.0
# MORTGAGE_TYPE_43.0
# MORTGAGE_TYPE_47.0
# ['LOAN_TYPE_694cbaee', 'LOAN_TYPE_0aeb4094', 'LOAN_TYPE_eab72d7a', 'LOAN_TYPE_95c4f8fb', 'LOAN_TYPE_f792971b', 'LOAN_TYPE_cde77491', 'LOAN_TYPE_47693941', 'LOAN_TYPE_8fe006f1']
# LOAN_TYPE_694cbaee
# LOAN_TYPE_eab72d7a
# LOAN_TYPE_95c4f8fb
# LOAN_TYPE_f792971b
# 0
# 0
# 0
# 0
# ...
#          Current function value: 0.014681
#          Iterations: 35
# ...

# %%
params={
    'RUN_NAME': 'default-1.58-1.90-640-11-140-0.005',
    'LR_R': 1.58,
    'RF_R': 1.90,
    'RF_N': 640,
    'RF_D': 11,
    'RF_L': 200,
    'FEATURES':0.005,
}
gen(params)

# %%
params={
    'RUN_NAME': 'default-1.68',
    'LR_R': 1.68,
    'RF_R': 2.08,
    'RF_N': 600,
    'RF_D': 11,
    'RF_L': 100,
    'FEATURES':0.005,
}
gen(params)
# Out:
# TARGET_EVENT_BINARY
# 0    1590792
# 1      10871
# Name: count, dtype: int64
# TARGET_EVENT_BINARY_2Y
# 0    1591751
# 1       9912
# Name: count, dtype: int64
# TARGET_EVENT_BINARY_1Y
# 0    1596927
# 1       4736
# Name: count, dtype: int64
# TARGET_EVENT_BINARY_6M
# 0    1601267
# 1        396
# Name: count, dtype: int64
# Variables removed: {'BORROWER_COUNTRY', 'CONTRACT_REFINANCED', 'FREQ_TYPE_2f88e16c'}
# LOAN_TYPE_47693941
# LOAN_TYPE_8fe006f1
# LOAN_TYPE_cde77491
# FREQ_TYPE_bd092d5a
# MORTGAGE_TYPE_3.0
# MORTGAGE_TYPE_10.0
# MORTGAGE_TYPE_41.0
# MORTGAGE_TYPE_42.0
# MORTGAGE_TYPE_43.0
# MORTGAGE_TYPE_47.0
# ['LOAN_TYPE_694cbaee', 'LOAN_TYPE_0aeb4094', 'LOAN_TYPE_eab72d7a', 'LOAN_TYPE_95c4f8fb', 'LOAN_TYPE_f792971b', 'LOAN_TYPE_cde77491', 'LOAN_TYPE_47693941', 'LOAN_TYPE_8fe006f1']
# LOAN_TYPE_694cbaee
# LOAN_TYPE_eab72d7a
# LOAN_TYPE_95c4f8fb
# LOAN_TYPE_f792971b
# 0
# 0
# 0
# 0
# ...
#          Current function value: 0.014681
#          Iterations: 35
# ...

# %%
params={
    'RUN_NAME': 'default-rf-d-10',
    'LR_R': 1.58,
    'RF_R': 2.08,
    'RF_N': 600,
    'RF_D': 10,
    'RF_L': 100,
    'FEATURES':0.005,
}
gen(params)
# Out:
# TARGET_EVENT_BINARY
# 0    1590792
# 1      10871
# Name: count, dtype: int64
# TARGET_EVENT_BINARY_2Y
# 0    1591751
# 1       9912
# Name: count, dtype: int64
# TARGET_EVENT_BINARY_1Y
# 0    1596927
# 1       4736
# Name: count, dtype: int64
# TARGET_EVENT_BINARY_6M
# 0    1601267
# 1        396
# Name: count, dtype: int64
# Variables removed: {'BORROWER_COUNTRY', 'CONTRACT_REFINANCED', 'FREQ_TYPE_2f88e16c'}
# LOAN_TYPE_47693941
# LOAN_TYPE_8fe006f1
# LOAN_TYPE_cde77491
# FREQ_TYPE_bd092d5a
# MORTGAGE_TYPE_3.0
# MORTGAGE_TYPE_10.0
# MORTGAGE_TYPE_41.0
# MORTGAGE_TYPE_42.0
# MORTGAGE_TYPE_43.0
# MORTGAGE_TYPE_47.0
# ['LOAN_TYPE_694cbaee', 'LOAN_TYPE_0aeb4094', 'LOAN_TYPE_eab72d7a', 'LOAN_TYPE_95c4f8fb', 'LOAN_TYPE_f792971b', 'LOAN_TYPE_cde77491', 'LOAN_TYPE_47693941', 'LOAN_TYPE_8fe006f1']
# LOAN_TYPE_694cbaee
# LOAN_TYPE_eab72d7a
# LOAN_TYPE_95c4f8fb
# LOAN_TYPE_f792971b
# 0
# 0
# 0
# 0
# ...
#          Current function value: 0.014681
#          Iterations: 35
# ...

# %%
params={
    'RUN_NAME': 'default-rf-l-50',
    'LR_R': 1.58,
    'RF_R': 2.08,
    'RF_N': 600,
    'RF_D': 11,
    'RF_L': 50,
    'FEATURES':0.005,
}
gen(params)
# Out:
# TARGET_EVENT_BINARY
# 0    1590792
# 1      10871
# Name: count, dtype: int64
# TARGET_EVENT_BINARY_2Y
# 0    1591751
# 1       9912
# Name: count, dtype: int64
# TARGET_EVENT_BINARY_1Y
# 0    1596927
# 1       4736
# Name: count, dtype: int64
# TARGET_EVENT_BINARY_6M
# 0    1601267
# 1        396
# Name: count, dtype: int64
# Variables removed: {'BORROWER_COUNTRY', 'CONTRACT_REFINANCED', 'FREQ_TYPE_2f88e16c'}
# LOAN_TYPE_47693941
# LOAN_TYPE_8fe006f1
# LOAN_TYPE_cde77491
# FREQ_TYPE_bd092d5a
# MORTGAGE_TYPE_3.0
# MORTGAGE_TYPE_10.0
# MORTGAGE_TYPE_41.0
# MORTGAGE_TYPE_42.0
# MORTGAGE_TYPE_43.0
# MORTGAGE_TYPE_47.0
# ['LOAN_TYPE_694cbaee', 'LOAN_TYPE_0aeb4094', 'LOAN_TYPE_eab72d7a', 'LOAN_TYPE_95c4f8fb', 'LOAN_TYPE_f792971b', 'LOAN_TYPE_cde77491', 'LOAN_TYPE_47693941', 'LOAN_TYPE_8fe006f1']
# LOAN_TYPE_694cbaee
# LOAN_TYPE_eab72d7a
# LOAN_TYPE_95c4f8fb
# LOAN_TYPE_f792971b
# 0
# 0
# 0
# 0
# ...
#          Current function value: 0.014681
#          Iterations: 35
# ...

# %%
params={
    'RUN_NAME': 'default-rf-n-500',
    'LR_R': 1.58,
    'RF_R': 2.08,
    'RF_N': 500,
    'RF_D': 11,
    'RF_L': 100,
    'FEATURES':0.005,
}
gen(params)
# Out:
# TARGET_EVENT_BINARY
# 0    1590792
# 1      10871
# Name: count, dtype: int64
# TARGET_EVENT_BINARY_2Y
# 0    1591751
# 1       9912
# Name: count, dtype: int64
# TARGET_EVENT_BINARY_1Y
# 0    1596927
# 1       4736
# Name: count, dtype: int64
# TARGET_EVENT_BINARY_6M
# 0    1601267
# 1        396
# Name: count, dtype: int64
# Variables removed: {'BORROWER_COUNTRY', 'CONTRACT_REFINANCED', 'FREQ_TYPE_2f88e16c'}
# LOAN_TYPE_47693941
# LOAN_TYPE_8fe006f1
# LOAN_TYPE_cde77491
# FREQ_TYPE_bd092d5a
# MORTGAGE_TYPE_3.0
# MORTGAGE_TYPE_10.0
# MORTGAGE_TYPE_41.0
# MORTGAGE_TYPE_42.0
# MORTGAGE_TYPE_43.0
# MORTGAGE_TYPE_47.0
# ['LOAN_TYPE_694cbaee', 'LOAN_TYPE_0aeb4094', 'LOAN_TYPE_eab72d7a', 'LOAN_TYPE_95c4f8fb', 'LOAN_TYPE_f792971b', 'LOAN_TYPE_cde77491', 'LOAN_TYPE_47693941', 'LOAN_TYPE_8fe006f1']
# LOAN_TYPE_694cbaee
# LOAN_TYPE_eab72d7a
# LOAN_TYPE_95c4f8fb
# LOAN_TYPE_f792971b
# 0
# 0
# 0
# 0
# ...
#          Current function value: 0.014681
#          Iterations: 35
# ...

# %%
params={
    'RUN_NAME': 'default-features-0.0051',
    'LR_R': 1.58,
    'RF_R': 2.08,
    'RF_N': 600,
    'RF_D': 11,
    'RF_L': 100,
    'FEATURES':0.0051,
}
gen(params)
# Out:
# TARGET_EVENT_BINARY
# 0    1590792
# 1      10871
# Name: count, dtype: int64
# TARGET_EVENT_BINARY_2Y
# 0    1591751
# 1       9912
# Name: count, dtype: int64
# TARGET_EVENT_BINARY_1Y
# 0    1596927
# 1       4736
# Name: count, dtype: int64
# TARGET_EVENT_BINARY_6M
# 0    1601267
# 1        396
# Name: count, dtype: int64
# Variables removed: {'BORROWER_COUNTRY', 'CONTRACT_REFINANCED', 'FREQ_TYPE_2f88e16c'}
# LOAN_TYPE_47693941
# LOAN_TYPE_8fe006f1
# LOAN_TYPE_cde77491
# FREQ_TYPE_bd092d5a
# MORTGAGE_TYPE_3.0
# MORTGAGE_TYPE_10.0
# MORTGAGE_TYPE_41.0
# MORTGAGE_TYPE_42.0
# MORTGAGE_TYPE_43.0
# MORTGAGE_TYPE_47.0
# ['LOAN_TYPE_694cbaee', 'LOAN_TYPE_0aeb4094', 'LOAN_TYPE_eab72d7a', 'LOAN_TYPE_95c4f8fb', 'LOAN_TYPE_f792971b', 'LOAN_TYPE_cde77491', 'LOAN_TYPE_47693941', 'LOAN_TYPE_8fe006f1']
# LOAN_TYPE_694cbaee
# LOAN_TYPE_eab72d7a
# LOAN_TYPE_95c4f8fb
# LOAN_TYPE_f792971b
# 0
# 0
# 0
# 0
# ...
#          Current function value: 0.014681
#          Iterations: 35
# ...

# %%
params={
    'RUN_NAME': 'default-features-0.0051',
    'LR_R': 1.58,
    'RF_R': 2.08,
    'RF_N': 600,
    'RF_D': 11,
    'RF_L': 100,
    'FEATURES':0.0051,
}
gen(params)
# Out:
# TARGET_EVENT_BINARY
# 0    1590792
# 1      10871
# Name: count, dtype: int64
# TARGET_EVENT_BINARY_2Y
# 0    1591751
# 1       9912
# Name: count, dtype: int64
# TARGET_EVENT_BINARY_1Y
# 0    1596927
# 1       4736
# Name: count, dtype: int64
# TARGET_EVENT_BINARY_6M
# 0    1601267
# 1        396
# Name: count, dtype: int64
# Variables removed: {'BORROWER_COUNTRY', 'CONTRACT_REFINANCED', 'FREQ_TYPE_2f88e16c'}
# LOAN_TYPE_47693941
# LOAN_TYPE_8fe006f1
# LOAN_TYPE_cde77491
# FREQ_TYPE_bd092d5a
# MORTGAGE_TYPE_3.0
# MORTGAGE_TYPE_10.0
# MORTGAGE_TYPE_41.0
# MORTGAGE_TYPE_42.0
# MORTGAGE_TYPE_43.0
# MORTGAGE_TYPE_47.0
# ['LOAN_TYPE_694cbaee', 'LOAN_TYPE_0aeb4094', 'LOAN_TYPE_eab72d7a', 'LOAN_TYPE_95c4f8fb', 'LOAN_TYPE_f792971b', 'LOAN_TYPE_cde77491', 'LOAN_TYPE_47693941', 'LOAN_TYPE_8fe006f1']
# LOAN_TYPE_694cbaee
# LOAN_TYPE_eab72d7a
# LOAN_TYPE_95c4f8fb
# LOAN_TYPE_f792971b
# 0
# 0
# 0
# 0
# ...
#          Current function value: 0.014681
#          Iterations: 35
# ...

# %%
params={
    'RUN_NAME': 'default-features-0.0065',
    'LR_R': 1.58,
    'RF_R': 2.08,
    'RF_N': 600,
    'RF_D': 11,
    'RF_L': 100,
    'FEATURES':0.0065,
}
gen(params)
# Out:
# TARGET_EVENT_BINARY
# 0    1590792
# 1      10871
# Name: count, dtype: int64
# TARGET_EVENT_BINARY_2Y
# 0    1591751
# 1       9912
# Name: count, dtype: int64
# TARGET_EVENT_BINARY_1Y
# 0    1596927
# 1       4736
# Name: count, dtype: int64
# TARGET_EVENT_BINARY_6M
# 0    1601267
# 1        396
# Name: count, dtype: int64
# Variables removed: {'BORROWER_COUNTRY', 'CONTRACT_REFINANCED', 'FREQ_TYPE_2f88e16c'}
# LOAN_TYPE_47693941
# LOAN_TYPE_8fe006f1
# LOAN_TYPE_cde77491
# FREQ_TYPE_bd092d5a
# MORTGAGE_TYPE_3.0
# MORTGAGE_TYPE_10.0
# MORTGAGE_TYPE_41.0
# MORTGAGE_TYPE_42.0
# MORTGAGE_TYPE_43.0
# MORTGAGE_TYPE_47.0
# ['LOAN_TYPE_694cbaee', 'LOAN_TYPE_0aeb4094', 'LOAN_TYPE_eab72d7a', 'LOAN_TYPE_95c4f8fb', 'LOAN_TYPE_f792971b', 'LOAN_TYPE_cde77491', 'LOAN_TYPE_47693941', 'LOAN_TYPE_8fe006f1']
# LOAN_TYPE_694cbaee
# LOAN_TYPE_eab72d7a
# LOAN_TYPE_95c4f8fb
# LOAN_TYPE_f792971b
# 0
# 0
# 0
# 0
# ...
#          Current function value: 0.014681
#          Iterations: 35
# ...

# %%
params={
    'RUN_NAME': 'default-features-0.0051-2.08-1.68-600-11-90',
    'LR_R': 1.68,
    'RF_R': 2.08,
    'RF_N': 600,
    'RF_D': 11,
    'RF_L': 90,
    'FEATURES':0.0051,
}
gen(params)

# %%
params={
    'RUN_NAME': 'default-features-0.0051-2.08-1.68-700-11-90',
    'LR_R': 1.68,
    'RF_R': 2.08,
    'RF_N': 700,
    'RF_D': 11,
    'RF_L': 90,
    'FEATURES':0.0051,
}
gen(params)

# %%
params={
    'RUN_NAME': 'default-features-0.0051-2.08-1.68-700-11-150',
    'LR_R': 1.68,
    'RF_R': 2.08,
    'RF_N': 700,
    'RF_D': 11,
    'RF_L': 150,
    'FEATURES':0.0051,
}
gen(params)

# %%
params={
    'RUN_NAME': 'default-features-0.0061-1.90-1.68-600-11-90',
    'LR_R': 1.68,
    'RF_R': 1.90,
    'RF_N': 600,
    'RF_D': 10,
    'RF_L': 100,
    'FEATURES':0.0061,
}
gen(params)
